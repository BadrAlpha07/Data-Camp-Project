# %% [markdown]
# ### 0. Installing & Importing dependencies

# %%
#import sys
#!{sys.executable} -m pip install requests
#!{sys.executable} -m pip install html5lib
#!{sys.executable} -m pip install bs4
#!{sys.executable} -m pip install bs4 selenium

# %%
import re
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pandas import DataFrame
from datetime import datetime
import numpy as np
import pandas as pd
from parse import search
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import scrapping_functions
from scrapping_functions import Scrapper

# %% [markdown]
# ### 1. Retriving top 49 World Influencers

# %%
driver_path = r"C:\Users\basti\DataCamp\Projet Groupe\chromedriver.exe"
scrapper = Scrapper(driver_path)
influencers, links = scrapper.get_influencers_world()

# %%
influencers
# Out:
#                                  Links to profile                   Name  \
# 0            https://www.instagram.com/cristiano/      Cristiano Ronaldo
# 1         https://www.instagram.com/arianagrande/          Ariana Grande
# 2              https://www.instagram.com/therock/         Dwayne Johnson
# 3          https://www.instagram.com/kyliejenner/           Kylie Jenner
# 4          https://www.instagram.com/selenagomez/           Selena Gomez
# 5        https://www.instagram.com/kimkardashian/         Kim Kardashian
# 6             https://www.instagram.com/leomessi/           Lionel Messi
# 7              https://www.instagram.com/beyonce/                Beyoncé
# 8         https://www.instagram.com/justinbieber/          Justin Bieber
# 9               https://www.instagram.com/natgeo/    National Geographic
# 10       https://www.instagram.com/kendalljenner/         Kendall Jenner
# 11            https://www.instagram.com/neymarjr/              Neymar Jr
# 12         https://www.instagram.com/taylorswift/           Taylor Swift
# 13                 https://www.instagram.com/jlo/         Jennifer Lopez
# 14                https://www.instagram.com/nike/                   Nike
# 15          https://www.instagram.com/nickiminaj/            Nicki Minaj
# 16    https://www.instagram.com/khloe kardashian/       Khloé Kardashian
# 17          https://www.instagram.com/mileycyrus/            Miley Cyrus
# 18           https://www.instagram.com/katyperry/             Katy Perry
# 19     https://www.instagram.com/kourtneykardash/    Kourtney Kardashian
# 20      https://www.instagram.com/kevinhart4real/             Kevin Hart
# 21            https://www.instagram.com/ddlovato/            Demi Lovato
# 22          https://www.instagram.com/realmadrid/         Real Madrid CF
# 23        https://www.instagram.com/theellenshow/        Ellen DeGeneres
# 24         https://www.instagram.com/fcbarcelona/           FC Barcelone
# 25          https://www.instagram.com/badgalriri/                Rihanna
# 26         https://www.instagram.com/virat.kohli/            Virat Kohli
# 27             https://www.instagram.com/zendaya/                Zendaya
# 28           https://www.instagram.com/iamcardib/                Cardi B
# 29           https://www.instagram.com/kingjames/           LeBron James
# 30  https://www.instagram.com/chrisbrownofficial/            Chris Brown
# 31       https://www.instagram.com/champagnepapi/                  Drake
# 32       https://www.instagram.com/billieeillish/          Billie Eilish
# 33             https://www.instagram.com/shakira/                Shakira
# 34     https://www.instagram.com/victoriassecret/      Victoria's Secret
# 35           https://www.instagram.com/vindiesel/             Vin Diesel
# 36     https://www.instagram.com/championsleague/  UEFA Champions League
# 37        https://www.instagram.com/davidbeckham/          David Beckham
# 38                https://www.instagram.com/nasa/                   NASA
# 39           https://www.instagram.com/gigihadid/             Gigi Hadid
# 40    https://www.instagram.com/justintimberlake/      Justin Timberlake
# 41      https://www.instagram.com/priyankachopra/        Priyanka Chopra
# 42          https://www.instagram.com/emmawatson/            Emma Watson
# 43         https://www.instagram.com/shawnmendes/           Shawn Mendes
# 44             https://www.instagram.com/dualipa/               Dua Lipa
# 45      https://www.instagram.com/shraddhakapoor/        Shraddha Kapoor
# 46              https://www.instagram.com/maluma/                 Maluma
# 47                https://www.instagram.com/9gag/                   9GAG
# 48           https://www.instagram.com/snoopdogg/             Snoop Dogg
#
#                                  Activity            Country Brand
# 0                             Footballeur           Portugal   Non
# 1                   Musicienne et actrice         États-Unis   Non
# 2        Acteur et catcheur professionnel         États-Unis   Non
# 3             Personnalité de téléréalité         États-Unis   Non
# 4                   Musicienne et actrice         États-Unis   Non
# 5             Personnalité de téléréalité         États-Unis   Non
# 6                             Footballeur          Argentine   Non
# 7                              Musicienne         États-Unis   Non
# 8                                Musicien             Canada   Non
# 9                                Magazine         États-Unis   Oui
# 10  Personnalité de téléréalité et modèle         États-Unis   Non
# 11                            Footballeur             Brésil   Non
# 12                             Musicienne         États-Unis   Non
# 13                  Musicienne et actrice         États-Unis   Non
# 14                              Vêtements         États-Unis   Oui
# 15                             Musicienne  Trinité-et-Tobago   Non
# 16            personnalité de téléréalité         États-Unis   Non
# 17                  Musicienne et actrice         États-Unis   Non
# 18                             Musicienne         États-Unis   Non
# 19            Personnalité de téléréalité         États-Unis   Non
# 20                                 Acteur         États-Unis   Non
# 21                  Musicienne et actrice         États-Unis   Non
# 22                       Club de football            Espagne   Oui
# 23                             Comédienne         États-Unis   Non
# 24                       Club de football            Espagne   Oui
# 25                             Musicienne            Barbade   Non
# 26                      Joueur de cricket               Inde   Non
# 27                  Actrice et musicienne         États-Unis   Non
# 28                             Musicienne         États-Unis   Non
# 29                  Joueur de basket-ball         États-Unis   Non
# 30                               Musicien         États-Unis   Non
# 31                               Musicien             Canada   Non
# 32                             Musicienne         États-Unis   Non
# 33                             Musicienne           Colombie   Non
# 34                               Lingerie         États-Unis   Oui
# 35                                 Acteur         États-Unis   Non
# 36                Compétition de football   Union Européenne   Oui
# 37                         Ex-Footballeur        Royaume-Uni   Non
# 38                        Agence spatiale         États-Unis   Oui
# 39                                 Modèle         États-Unis   Non
# 40                     Musicien et acteur         États-Unis   Non
# 41                  Actrice et musicienne               Inde   Non
# 42                                Actrice        Royaume-Uni   Non
# 43                               Musicien             Canada   Non
# 44                             Musicienne        Royaume-Uni   Non
# 45                                Actrice               Inde   Non
# 46                               Musicien           Colombie   Non
# 47                          Réseau social          Hong Kong   Oui
# 48                               Musicien         États-Unis   Non

# %%
links
# Out:
# ['https://www.instagram.com/cristiano/',
#  'https://www.instagram.com/arianagrande/',
#  'https://www.instagram.com/therock/',
#  'https://www.instagram.com/kyliejenner/',
#  'https://www.instagram.com/selenagomez/',
#  'https://www.instagram.com/kimkardashian/',
#  'https://www.instagram.com/leomessi/',
#  'https://www.instagram.com/beyonce/',
#  'https://www.instagram.com/justinbieber/',
#  'https://www.instagram.com/natgeo/',
#  'https://www.instagram.com/kendalljenner/',
#  'https://www.instagram.com/neymarjr/',
#  'https://www.instagram.com/taylorswift/',
#  'https://www.instagram.com/jlo/',
#  'https://www.instagram.com/nike/',
#  'https://www.instagram.com/nickiminaj/',
#  'https://www.instagram.com/khloe kardashian/',
#  'https://www.instagram.com/mileycyrus/',
#  'https://www.instagram.com/katyperry/',
#  'https://www.instagram.com/kourtneykardash/',
#  'https://www.instagram.com/kevinhart4real/',
#  'https://www.instagram.com/ddlovato/',
#  'https://www.instagram.com/realmadrid/',
#  'https://www.instagram.com/theellenshow/',
#  'https://www.instagram.com/fcbarcelona/',
#  'https://www.instagram.com/badgalriri/',
#  'https://www.instagram.com/virat.kohli/',
#  'https://www.instagram.com/zendaya/',
#  'https://www.instagram.com/iamcardib/',
#  'https://www.instagram.com/kingjames/',
#  'https://www.instagram.com/chrisbrownofficial/',
#  'https://www.instagram.com/champagnepapi/',
#  'https://www.instagram.com/billieeillish/',
#  'https://www.instagram.com/shakira/',
#  'https://www.instagram.com/victoriassecret/',
#  'https://www.instagram.com/vindiesel/',
#  'https://www.instagram.com/championsleague/',
#  'https://www.instagram.com/davidbeckham/',
#  'https://www.instagram.com/nasa/',
#  'https://www.instagram.com/gigihadid/',
#  'https://www.instagram.com/justintimberlake/',
#  'https://www.instagram.com/priyankachopra/',
#  'https://www.instagram.com/emmawatson/',
#  'https://www.instagram.com/shawnmendes/',
#  'https://www.instagram.com/dualipa/',
#  'https://www.instagram.com/shraddhakapoor/',
#  'https://www.instagram.com/maluma/',
#  'https://www.instagram.com/9gag/',
#  'https://www.instagram.com/snoopdogg/']

# %%
export_csv = influencers.to_csv (r'C:\Users\basti\DataCamp\Projet Groupe\data\influencer_list.csv', index = None, header=True)

# %% [markdown]
# ### 2. Retrieving influencers infos and their posts

# %%
# Selecting influencers to retrieve posts from
links_1 = links[1:20]
links_1
# Out:
# ['https://www.instagram.com/arianagrande/',
#  'https://www.instagram.com/therock/',
#  'https://www.instagram.com/kyliejenner/',
#  'https://www.instagram.com/selenagomez/',
#  'https://www.instagram.com/kimkardashian/',
#  'https://www.instagram.com/leomessi/',
#  'https://www.instagram.com/beyonce/',
#  'https://www.instagram.com/justinbieber/',
#  'https://www.instagram.com/natgeo/',
#  'https://www.instagram.com/kendalljenner/',
#  'https://www.instagram.com/neymarjr/',
#  'https://www.instagram.com/taylorswift/',
#  'https://www.instagram.com/jlo/',
#  'https://www.instagram.com/nike/',
#  'https://www.instagram.com/nickiminaj/',
#  'https://www.instagram.com/khloe kardashian/',
#  'https://www.instagram.com/mileycyrus/',
#  'https://www.instagram.com/katyperry/',
#  'https://www.instagram.com/kourtneykardash/']

# %%
driver_path = r"C:\Users\basti\DataCamp\Projet Groupe\chromedriver.exe"
instagram_account_link = links[1]
user_name = "datacamp46"
password= "$datacamp2021$"

# %%
data_frames=[]
pause_time = 6
for i in range(len(links_1[0:10])):
    browser = scrapper.connection_instagram(links_1[i], user_name, password)
    df = scrapper.get_influencer_posts(browser,links_1[i], pause_time)
    data_frames.append(df)
links_pub = pd.concat(data_frames)
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     386         else:
# --> 387             conn.request(method, url, **httplib_request_kw)
#     388
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# C:\ProgramData\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\ProgramData\Anaconda3\lib\http\client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     183     def connect(self):
# --> 184         conn = self._new_conn()
#     185         self._prepare_conn(conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e
#     170             )
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001F9494AB148>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# <ipython-input-8-c253ed02a1cd> in <module>
#       2 pause_time = 6
#       3 for i in range(len(links_1[0:10])):
# ----> 4     browser = scrapper.connection_instagram(links_1[i], user_name, password)
#       5     df = scrapper.get_influencer_posts(browser,links_1[i], pause_time)
#       6     data_frames.append(df)
#
# ~\DataCamp\Projet Groupe\scrapping_functions.py in connection_instagram(self, instagram_account_link, user_name, password)
#     109         user = self.user
#     110         pwd = self.pwd
# --> 111         browser.get(instagram_account_link)
#     112         cookies_click = browser.find_element_by_xpath("//button[text()='Accepter']")
#     113         cookies_click.click()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     328             response = conn.urlopen(method, url, **kw)
#     329         else:
# --> 330             response = conn.urlopen(method, u.request_uri, **kw)
#     331
#     332         redirect_location = redirect and response.get_redirect_location()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     758                 chunked=chunked,
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#     762
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     718
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#     722             retries.sleep()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     434
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#     438         log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=56944): Max retries exceeded with url: /session/0fd10da79d4c3545ab2c52d6f88d8ce7/url (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001F9494AB148>: Failed to establish a new connection: [WinError 10061] Aucune connexion n’a pu être établie car l’ordinateur cible l’a expressément refusée'))

# %%
links_pub

# %%
export_csv = links_pub.to_csv (r'C:\Users\bastien\Documents\DataCamp\publis_1.csv', index = None, header=True)

# %% [markdown]
# ### 3. Retrieving posts' infos

# %%
publications = pd.read_csv(r'C:\Users\bastien\Documents\DataCamp\publis_1.csv')

# %%
links = publications[publications["Name Account/Influencer"]=="Cristiano Ronaldo"]
pub_list = links["Links to publication"].tolist()
pub_list

# %%
driver_path = r"C:\Users\bastien\Documents\DataCamp\chromedriver"
instagram_account_link = pub_list[1]
user_name = "datacamp46"
password= "$datacamp2021$"

df = get_pub_infos(pub_list, driver_path, instagram_account_link, user_name, password)

# %%
df_1 = publications[publications["Name Account/Influencer"]=="Cristiano Ronaldo"]

# %%
df_2 = df_1.join(df,lsuffix='_gen_info', rsuffix='_pub_info')

# %% [markdown]
# ### 4. Export

# %%
export_csv = df.to_csv (r'C:\Users\bastien\Documents\DataCamp\influencers_but_cr7.csv', index = None, header=True)
